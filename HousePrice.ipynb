# %% [markdown]
# # House Prices - Advanced Regression Techniques and EDA

# %% [markdown]
# # Introduction
#
# Ever wondering why two identical houses could have such a significant difference in price and what has caused it? I'm no real-estate agent but I'm curious just as you are. House prices are mysterious and driven by so many variables: year, location, land size, garage size, number of bathrooms, etc. What is the number one driving factor and what is number two? Do neighborhoods affect the price as much as the overall quality? Are house prices predictable if we know all of those information? Let's find out.

# %% [markdown]
# # Data Set
#
# The Ames Housing dataset was compiled by Dean De Cock for use in data science education. It's an incredible alternative for data scientists looking for a modernized and expanded version of the often cited Boston Housing dataset.

# %% [markdown]
# # Goal
# In this project, my goal is to find out and visualize the most important factor(s) that make(s) houses vary in price, use machine-learning models to predict the prices of houses given in the testing dataset, and acheive as low as possible a root mean squared logarithmic error.

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np

#Plotly Libraris
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.colors import n_colors
from plotly.subplots import make_subplots
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from IPython.display import display, HTML

#Sklearn
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score, RandomizedSearchCV
from sklearn.linear_model import ElasticNet, LinearRegression, Ridge, Lasso
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, RobustScaler   
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

#XGBOOST
from xgboost import XGBRegressor

# %%
train = pd.read_csv('C:/Project/HousePrice/train.csv')
test = pd.read_csv('C:/Project/HousePrice/test.csv')
all_data = pd.concat((train, test)).reset_index(drop=True)
ntrain = train.shape[0]
ntest = test.shape[0]
target = train['SalePrice']
all_data = all_data.drop('SalePrice',axis = 1)

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
all_data.shape
# Out:
# (2919, 80)

# %%
all_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1       float64
# BsmtFinType2      object
# BsmtFinSF2       float64
# ...

# %%
all_data.head(15)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
all_data['OverallQual'] = all_data['OverallQual'].astype('str')
all_data['OverallCond'] = all_data['OverallCond'].astype('str')

# %%
print(all_data.isnull().sum())
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
# Street              0
# Alley            2721
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         24
# MasVnrArea         23
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           81
# BsmtCond           82
# BsmtExposure       82
# BsmtFinType1       79
# BsmtFinSF1          1
# BsmtFinType2       80
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %%
#drop columns which have more than 15% of missing values
columns_to_drop = list()
for name in all_data.columns:
    if all_data[name].isnull().sum() / all_data[name].count() >= 0.15:
        columns_to_drop.append(name)
print('Columns that have more than 15 percent of missing vlaues: {}'.format(columns_to_drop))
# Out:
# Columns that have more than 15 percent of missing vlaues: ['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %%
#all_data.drop(columns_to_drop,axis = 1, inplace=True)

# %%
print(all_data.shape)
# Out:
# (2919, 80)

# %%
print(all_data.isnull().sum())
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
# Street              0
# Alley            2721
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         24
# MasVnrArea         23
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           81
# BsmtCond           82
# BsmtExposure       82
# BsmtFinType1       79
# BsmtFinSF1          1
# BsmtFinType2       80
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %%
all_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual       object
# OverallCond       object
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1       float64
# BsmtFinType2      object
# BsmtFinSF2       float64
# ...

# %%
print(all_data.isnull().sum())
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
# Street              0
# Alley            2721
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         24
# MasVnrArea         23
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           81
# BsmtCond           82
# BsmtExposure       82
# BsmtFinType1       79
# BsmtFinSF1          1
# BsmtFinType2       80
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %%
cols = all_data.select_dtypes([np.object]).columns
print(cols)
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir',
#        'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC',
#        'Fence', 'MiscFeature', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
for name in cols:
    all_data[name] = all_data[name].fillna("None")

# %%
all_data.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      486
# LotArea            0
# Street             0
# Alley              0
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         0
# MasVnrArea        23
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual           0
# BsmtCond           0
# BsmtExposure       0
# BsmtFinType1       0
# BsmtFinSF1         1
# BsmtFinType2       0
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         0
# ...

# %%
all_data = pd.get_dummies(all_data)

# %%
train = all_data[:ntrain]
test = all_data[ntrain:]

# %%
imp_median = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
y = target.values
X = train.values

# %%
steps = [('imputation', SimpleImputer(missing_values=np.nan)),
         ('scaler', StandardScaler()),
         ('elasticnet', ElasticNet())]

# %%
pipeline = Pipeline(steps)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state = 62)

# %%
parameters = {'elasticnet__l1_ratio':np.linspace(0,1,30)}

# %%
gm_cv = GridSearchCV(pipeline,parameters)

# %%
gm_cv.fit(X_train,y_train)
# Out:
# C:\Users\John\anaconda3\envs\myenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 363595643585.18835, tolerance: 451242506.26750356
#
# C:\Users\John\anaconda3\envs\myenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 350851045450.8772, tolerance: 466947502.569993
#
# C:\Users\John\anaconda3\envs\myenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 400618564173.0318, tolerance: 493726468.7997555
#
# C:\Users\John\anaconda3\envs\myenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# ...

# %%
y_pred = gm_cv.predict(X_test)

# %%
r2 = gm_cv.score(X_test, y_test)
print("Tuned ElasticNet Alpha: {}".format(gm_cv.best_params_))
print("Tuned ElasticNet R squared: {}".format(r2))
# Out:
# Tuned ElasticNet Alpha: {'elasticnet__l1_ratio': 0.8275862068965517}
# Tuned ElasticNet R squared: 0.7270141257425049

# %%
gm_cv.score(X_test,y_test)
# Out:
# 0.7270141257425049

# %%
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 44839.07557810067

# %%
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 2914  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2915  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2916  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2917  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2918  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
from xgboost import XGBRegressor

# %%
xgb = XGBRegressor()

# %%
xgb.fit(X_train, y_train, verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=12, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgb_y_pred = xgb.predict(X_test)

# %%
print("Mean Absolute Error : " + str(mean_absolute_error(xgb_y_pred, y_test)))
# Out:
# Mean Absolute Error : 20087.175121289954

# %%
xgb.score(X_test,y_test)
# Out:
# 0.7668167858082828

# %%
xgb_parameters = {'n_estimators':[1000,1500,2000],
                  'learning_rate':[0.05,0.1,0.15],
                  'early_stopping_rounds':[4,6,8]
}

# %%
cv_xgb = RandomizedSearchCV(xgb, param_distributions=xgb_parameters, n_jobs=4, cv=5,random_state=62)

# %%
cv_xgb.fit(X_train,y_train)
# Out:
# [13:33:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { early_stopping_rounds } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                           colsample_bylevel=1,
#                                           colsample_bynode=1,
#                                           colsample_bytree=1, gamma=0,
#                                           gpu_id=-1, importance_type='gain',
#                                           interaction_constraints='',
#                                           learning_rate=0.300000012,
# ...

# %%
cv_xgb.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, early_stopping_rounds=4,
#              gamma=0, gpu_id=-1, importance_type='gain',
#              interaction_constraints='', learning_rate=0.15, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=1500, n_jobs=12,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_pred = cv_xgb.predict(X_test)

# %%
mean_absolute_error(y_pred, y_test)
# Out:
# 19029.611791880707

# %%
x_test = test.values

# %%
y_pred = cv_xgb.predict(x_test)

# %%
sub = pd.DataFrame()
sub['Id'] = test['Id']
sub['SalePrice'] = y_pred

# %%
sub.to_csv('submission.csv',index=False)
